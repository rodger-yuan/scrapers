# %%
from collections import defaultdict
import re

from bs4 import BeautifulSoup
from urllib import urlopen
import pandas as pd

base_url = 'http://www.basketball-reference.com/leagues/NBA_'
year_start = 1985
year_end = 2017

def get_html(url): #inputs url and returns html
    page =  urlopen(url).read()
    return page

def get_all_name_url_dict(year_start, year_end): #gets dict of all player-stat year urls
    url_dict = defaultdict(dict)
    for year in range(year_start,year_end+1):
        year_url = base_url + str(year) + '_per_game.html'
        url_dict[str(year)] = year_url
    return url_dict

def parse_player_stats_html(html): #
    player_stats_parser = BeautifulSoup(html, 'html.parser')
    player_list = []
    player_list_temp = []
    player_id_list = []
    player_id_list_temp = []             
    for tag in player_stats_parser.find_all('td',{'data-stat':'player'}): #
        player_name_tag = tag.find('a')
        player_list_temp.append(player_name_tag.string)
        player_id_attr = tag["data-append-csv"]
        player_id_list_temp.append(player_id_attr)
    for item in player_list_temp: #remove duplicates
        if item not in player_list:
            player_list.append(item)
    for item in player_id_list_temp:
        if item not in player_id_list:
            player_id_list.append(item)
    return [player_list,player_id_list]

def combine_player_lists(year_start,year_end): #combining player and player_id lists while removing duplicates
    player_id_list_all = []
    player_list_all = []              
    for year, url in get_all_name_url_dict(year_start,year_end).items():
        html = get_html(url)
        player_list = parse_player_stats(html)
        for item in player_list[0]:
            if item not in player_id_list_all:
                player_id_list_all.append(item)
        for item in player_list[1]:
            if item not in player_list_all:
                player_list_all.append(item)
    return [player_id_list_all, player_list_all]

# %%
url_list = get_all_name_url_dict(year_start, year_end)
url = url_list['1985']
html = get_html(url)
player_stats_parser = BeautifulSoup(html, 'html.parser')
a = player_stats_parser.find('td',{'data-stat':'player'})
a["data-append-csv"]
# Out:
# u'abdulka01'

# %%
url_list = get_all_name_url_dict(year_start, year_end)
url = url_list['1985']
html = get_html(url)
parse_player_stats_html(html)
# Out:
# [[u'Kareem Abdul-Jabbar',
#   u'Alvan Adams',
#   u'Mark Aguirre',
#   u'Danny Ainge',
#   u'Chuck Aleksinas',
#   u'J.J. Anderson',
#   u'Ron Anderson',
#   u'John Bagley',
#   u'James Bailey',
#   u'Thurl Bailey',
#   u'Greg Ballard',
#   u'Gene Banks',
#   u'Ken Bannister',
#   u'Charles Barkley',
#   u'Kent Benson',
#   u'Larry Bird',
#   u'Otis Birdsong',
#   u'Rolando Blackman',
#   u'Cory Blackwell',
#   u'Sam Bowie',
#   u'Dudley Bradley',
#   u'Mike Bratz',
#   u'Randy Breuer',
#   u'Ron Brewer',
#   u'Frank Brickowski',
#   u'Junior Bridgeman',
#   u'Rickey Brown',
#   u'Tony Brown',
#   u'Wallace Bryant',
#   u'Quinn Buckner',
#   u'Steve Burtt',
#   u'Don Buse',
#   u'Michael Cage',
#   u'Tony Campbell',
#   u'Rick Carlisle',
#   u'Antoine Carr',
#   u'Kenny Carr',
#   u'M.L. Carr',
#   u'Butch Carter',
#   u'Howard Carter',
#   u'Harvey Catchings',
#   u'Ron Cavenall',
#   u'Tom Chambers',
#   u'Maurice Cheeks',
#   u'Carlos Clark',
#   u'Don Collins',
#   u'Steve Colter',
#   u'Lester Conner',
#   u'Darwin Cook',
#   u'Jeff Cook',
#   u'Joe Cooper',
#   u'Michael Cooper',
#   u'Wayne Cooper',
#   u'Dave Corzine',
#   u'Charlie Criss',
#   u'Pat Cummings',
#   u'Terry Cummings',
#   u'Earl Cureton',
#   u'Quintin Dailey',
#   u'Adrian Dantley',
#   u'Brad Davis',
#   u'Charles Davis',
#   u'Johnny Davis',
#   u'Walter Davis',
#   u'Darryl Dawkins',
#   u'Darren Daye',
#   u'James Donaldson',
#   u'John Drew',
#   u'Larry Drew',
#   u'Clyde Drexler',
#   u'Mike Dunleavy',
#   u'T.R. Dunn',
#   u'Devin Durrant',
#   u'Mark Eaton',
#   u'Jerry Eaves',
#   u'Kenton Edelin',
#   u'Franklin Edwards',
#   u'James Edwards',
#   u'Craig Ehlo',
#   u'Dale Ellis',
#   u'Chris Engler',
#   u'Alex English',
#   u'Julius Erving',
#   u'Mike Evans',
#   u'Kenny Fields',
#   u'Vern Fleming',
#   u'Sleepy Floyd',
#   u'Phil Ford',
#   u'Rod Foster',
#   u'World B. Free',
#   u'Bill Garnett',
#   u'George Gervin',
#   u'Artis Gilmore',
#   u'Mike Glenn',
#   u'Mike Gminski',
#   u'Lancaster Gordon',
#   u'Stewart Granger',
#   u'Butch Graves',
#   u'Stuart Gray',
#   u'Rickey Green',
#   u'Sidney Green',
#   u'Dave Greenwood',
#   u'Kevin Grevey',
#   u'Darrell Griffith',
#   u'Ernie Grunfeld',
#   u'Bob Hansen',
#   u'Bill Hanzlik',
#   u'Derek Harper',
#   u'Scott Hastings',
#   u'Steve Hayes',
#   u'Gerald Henderson',
#   u'Rod Higgins',
#   u'Roy Hinson',
#   u'Craig Hodges',
#   u'Lionel Hollins',
#   u'Mike Holton',
#   u'Phil Hubbard',
#   u'Jay Humphries',
#   u'Geoff Huston',
#   u'Marc Iavaroni',
#   u'Dan Issel',
#   u'Ralph Jackson',
#   u'Clemon Johnson',
#   u'Dennis Johnson',
#   u'Eddie Johnson',
#   u'Frank Johnson',
#   u'George Johnson',
#   u'Magic Johnson',
#   u'Marques Johnson',
#   u'Mickey Johnson',
#   u'Steve Johnson',
#   u'Vinnie Johnson',
#   u'Bobby Jones',
#   u'Caldwell Jones',
#   u'Charles Jones',
#   u'Earl Jones',
#   u'Edgar Jones',
#   u'Major Jones',
#   u'Ozell Jones',
#   u'Michael Jordan',
#   u'Rich Kelley',
#   u'Clark Kellogg',
#   u'Greg Kelser',
#   u'Jerome Kersey',
#   u'Albert King',
#   u'Bernard King',
#   u'Reggie King',
#   u'Greg Kite',
#   u'Billy Knight',
#   u'Joe Kopicki',
#   u'Mitch Kupchak',
#   u'Tom LaGarde',
#   u'Bill Laimbeer',
#   u'Allen Leavell',
#   u'Ronnie Lester',
#   u'Fat Lever',
#   u'Cliff Levingston',
#   u'Alton Lister',
#   u'Lewis Lloyd',
#   u'John Long',
#   u'Sidney Lowe',
#   u'John Lucas',
#   u'Maurice Lucas',
#   u'Kyle Macy',
#   u'Rick Mahorn',
#   u'Jeff Malone',
#   u'Moses Malone',
#   u'Pace Mannion',
#   u'Wes Matthews',
#   u'Cedric Maxwell',
#   u'Bob McAdoo',
#   u'Tim McCormick',
#   u'Rodney McCray',
#   u'Scooter McCray',
#   u'Hank McDowell',
#   u'Mike McGee',
#   u'Kevin McHale',
#   u'Kevin McKenna',
#   u'Tom McMillen',
#   u'Mark McNamara',
#   u'Joe Meriweather',
#   u'Larry Micheaux',
#   u'Mike Mitchell',
#   u'Paul Mokeski',
#   u'Sidney Moncrief',
#   u'Johnny Moore',
#   u'Jay Murphy',
#   u'Larry Nance',
#   u'Calvin Natt',
#   u'Kenny Natt',
#   u'Ed Nealy',
#   u'Chuck Nevitt',
#   u'Kurt Nimphius',
#   u'Norm Nixon',
#   u'Audie Norris',
#   u"Mike O'Koren",
#   u'Hakeem Olajuwon',
#   u'Mark Olberding',
#   u'Jawann Oldham',
#   u'Louis Orr',
#   u'Robert Parish',
#   u'Billy Paultz',
#   u'Jim Paxson',
#   u'John Paxson',
#   u'Sam Perkins',
#   u'Jim Petersen',
#   u'Ricky Pierce',
#   u'Charles Pittman',
#   u'Gary Plummer',
#   u'David Pope',
#   u'Ben Poquette',
#   u'Paul Pressey',
#   u'Kurt Rambis',
#   u'Kelvin Ransey',
#   u'Leo Rautins',
#   u'Robert Reid',
#   u'Clint Richardson',
#   u'Micheal Ray Richardson',
#   u'Doc Rivers',
#   u'Fred Roberts',
#   u'Alvin Robertson',
#   u'Rick Robey',
#   u'Cliff Robinson',
#   u'Truck Robinson',
#   u'Tree Rollins',
#   u'Lorenzo Romar',
#   u'Dan Roundfield',
#   u'Jeff Ruland',
#   u'Campy Russell',
#   u'Walker Russell',
#   u'Ralph Sampson',
#   u'Mike Sanders',
#   u'Wayne Sappleton',
#   u'Danny Schayes',
#   u'Tom Scheffler',
#   u'John Schweitz',
#   u'Alvin Scott',
#   u'Byron Scott',
#   u'Tom Sewell',
#   u'Lonnie Shelton',
#   u'Purvis Short',
#   u'Jerry Sichting',
#   u'Jack Sikma',
#   u'Charlie Sitton',
#   u'Tom Sluby',
#   u'Derek Smith',
#   u'Larry Smith',
#   u'Robert Smith',
#   u'Ricky Sobers',
#   u'Rory Sparrow',
#   u'Larry Spriggs',
#   u'Terence Stansbury',
#   u'Brook Steppe',
#   u'Steve Stipanovich',
#   u'John Stockton',
#   u'Jon Sundvold',
#   u'Dane Suttle',
#   u'Terry Teagle',
#   u'Reggie Theus',
#   u'Peter Thibeaux',
#   u'David Thirdkill',
#   u'Isiah Thomas',
#   u'Jim Thomas',
#   u'Bernard Thompson',
#   u'LaSalle Thompson',
#   u'Mychal Thompson',
#   u'Paul Thompson',
#   u'Otis Thorpe',
#   u'Sedale Threatt',
#   u'Andrew Toney',
#   u'Linton Townes',
#   u'Kelly Tripucka',
#   u'Trent Tucker',
#   u'Elston Turner',
#   u'Jeff Turner',
#   u'Melvin Turpin',
#   u'Terry Tyler',
#   u'Darnell Valentine',
#   u'Kiki Vandeweghe',
#   u'Pete Verhoeven',
#   u'Jay Vincent',
#   u'Danny Vranes',
#   u'Granville Waiters',
#   u'Darrell Walker',
#   u'Bill Walton',
#   u'Bryan Warrick',
#   u'Scott Wedman',
#   u'Mark West',
#   u'Ennis Whatley',
#   u'Rory White',
#   u'Willie White',
#   u'Jerome Whitehead',
#   u'Mitchell Wiggins',
#   u'Jamaal Wilkes',
#   u'Dominique Wilkins',
#   u'Eddie Lee Wilkins',
#   u'Jeff Wilkins',
#   u'Dale Wilkinson',
#   u'Buck Williams',
#   u'Gus Williams',
#   u'Guy Williams',
#   u'Herb Williams',
#   u'Kevin Williams',
#   u'Ray Williams',
#   u'Sam Williams',
#   u'Sly Williams',
#   u'Kevin Willis',
#   u'Michael Wilson',
#   u'Othell Wilson',
#   u'Randy Wittman',
#   u'Al Wood',
#   u'Leon Wood',
#   u'Mike Woodson',
#   u'Orlando Woolridge',
#   u'James Worthy',
#   u'Danny Young',
#   u'Michael Young'],
#  [u'abdulka01',
#   u'adamsal01',
#   u'aguirma01',
#   u'aingeda01',
#   u'aleksch01',
#   u'anderjj01',
#   u'anderro01',
#   u'baglejo01',
#   u'baileja01',
#   u'baileth01',
#   u'ballagr01',
#   u'banksge01',
#   u'bannike01',
#   u'barklch01',
#   u'bensoke01',
#   u'birdla01',
#   u'birdsot01',
#   u'blackro01',
#   u'blackco01',
#   u'bowiesa01',
#   u'bradldu01',
#   u'bratzmi01',
#   u'breuera01',
#   u'brewero01',
#   u'brickfr01',
#   u'bridgju01',
#   u'brownri01',
#   u'brownto01',
#   u'bryanwa01',
#   u'bucknqu01',
#   u'burttst01',
#   u'busedo01',
#   u'cagemi01',
#   u'campbto01',
#   u'carliri01',
#   u'carran01',
#   u'carrke01',
#   u'carrml01',
#   u'cartebu01',
#   u'carteho01',
#   u'catchha01',
#   u'cavenro01',
#   u'chambto01',
#   u'cheekma01',
#   u'clarkca01',
#   u'collido02',
#   u'coltest01',
#   u'connele01',
#   u'cookda01',
#   u'cookje01',
#   u'coopejo01',
#   u'coopemi01',
#   u'coopewa01',
#   u'corzida01',
#   u'crissch01',
#   u'cummipa01',
#   u'cummite01',
#   u'curetea01',
#   u'dailequ01',
#   u'dantlad01',
#   u'davisbr01',
#   u'davisch02',
#   u'davisjo01',
#   u'daviswa03',
#   u'dawkida01',
#   u'dayeda01',
#   u'donalja01',
#   u'drewjo01',
#   u'drewla01',
#   u'drexlcl01',
#   u'dunlemi01',
#   u'dunntr01',
#   u'durrade01',
#   u'eatonma01',
#   u'eavesje01',
#   u'edelike01',
#   u'edwarfr01',
#   u'edwarja01',
#   u'ehlocr01',
#   u'ellisda01',
#   u'englech01',
#   u'englial01',
#   u'ervinju01',
#   u'evansmi01',
#   u'fieldke01',
#   u'flemive01',
#   u'floydsl01',
#   u'fordph01',
#   u'fostero01',
#   u'freewo01',
#   u'garnebi02',
#   u'gervige01',
#   u'gilmoar01',
#   u'glennmi01',
#   u'gminsmi01',
#   u'gordola01',
#   u'grangst01',
#   u'gravebu01',
#   u'grayst01',
#   u'greenri01',
#   u'greensi02',
#   u'greenda01',
#   u'greveke01',
#   u'griffda01',
#   u'grunfer01',
#   u'hansebo01',
#   u'hanzlbi01',
#   u'harpede01',
#   u'hastisc01',
#   u'hayesst01',
#   u'hendege01',
#   u'higgiro01',
#   u'hinsoro01',
#   u'hodgecr01',
#   u'hollili01',
#   u'holtomi01',
#   u'hubbaph01',
#   u'humphja01',
#   u'hustoge01',
#   u'iavarma01',
#   u'isselda01',
#   u'jacksra01',
#   u'johnscl01',
#   u'johnsde01',
#   u'johnsed02',
#   u'johnsed03',
#   u'johnsfr01',
#   u'johnsge02',
#   u'johnsge03',
#   u'johnsma02',
#   u'johnsma01',
#   u'johnsmi01',
#   u'johnsst03',
#   u'johnsvi01',
#   u'jonesbo01',
#   u'jonesca01',
#   u'jonesch02',
#   u'jonesch01',
#   u'jonesea01',
#   u'jonesed01',
#   u'jonesma01',
#   u'jonesoz01',
#   u'jordami01',
#   u'kelleri01',
#   u'kellocl01',
#   u'kelsegr01',
#   u'kerseje01',
#   u'kingal01',
#   u'kingbe01',
#   u'kingre01',
#   u'kitegr01',
#   u'knighbi01',
#   u'kopicjo01',
#   u'kupchmi01',
#   u'lagarto01',
#   u'laimbbi01',
#   u'leaveal01',
#   u'lestero01',
#   u'leverfa01',
#   u'levincl01',
#   u'listeal01',
#   u'lloydle01',
#   u'longjo01',
#   u'lowesi01',
#   u'lucasjo01',
#   u'lucasma01',
#   u'macyky01',
#   u'mahorri01',
#   u'malonje01',
#   u'malonmo01',
#   u'mannipa01',
#   u'matthwe01',
#   u'maxwece01',
#   u'mcadobo01',
#   u'mccorti01',
#   u'mccraro01',
#   u'mccrasc01',
#   u'mcdowha01',
#   u'mcgeemi01',
#   u'mchalke01',
#   u'mckenke01',
#   u'mcmilto01',
#   u'mcnamma01',
#   u'meriwjo01',
#   u'michela01',
#   u'mitchmi01',
#   u'mokespa01',
#   u'moncrsi01',
#   u'moorejo01',
#   u'murphja01',
#   u'nancela01',
#   u'nattca01',
#   u'nattke01',
#   u'nealyed01',
#   u'nevitch01',
#   u'nimphku01',
#   u'nixonno01',
#   u'norriau01',
#   u'okoremi01',
#   u'olajuha01',
#   u'olberma01',
#   u'oldhaja01',
#   u'orrlo01',
#   u'parisro01',
#   u'paultbi01',
#   u'paxsoji02',
#   u'paxsojo01',
#   u'perkisa01',
#   u'peterji01',
#   u'piercri01',
#   u'pittmch01',
#   u'plummga01',
#   u'popeda01',
#   u'poquebe01',
#   u'presspa01',
#   u'rambiku01',
#   u'ranseke01',
#   u'rautile01',
#   u'reidro01',
#   u'richacl01',
#   u'richami01',
#   u'riverdo01',
#   u'roberfr01',
#   u'roberal01',
#   u'robeyri01',
#   u'robincl01',
#   u'robintr01',
#   u'rollitr01',
#   u'romarlo01',
#   u'roundda01',
#   u'rulanje01',
#   u'russeca02',
#   u'russewa01',
#   u'sampsra01',
#   u'sandemi01',
#   u'sapplwa01',
#   u'schayda01',
#   u'schefto01',
#   u'schwejo01',
#   u'scottal01',
#   u'scottby01',
#   u'sewelto01',
#   u'sheltlo01',
#   u'shortpu01',
#   u'sichtje01',
#   u'sikmaja01',
#   u'sittoch01',
#   u'slubyto01',
#   u'smithde02',
#   u'smithla01',
#   u'smithro01',
#   u'soberri01',
#   u'sparrro01',
#   u'sprigla01',
#   u'stanste01',
#   u'steppbr01',
#   u'stipast01',
#   u'stockjo01',
#   u'sundvjo01',
#   u'suttlda01',
#   u'teaglte01',
#   u'theusre01',
#   u'thibepe01',
#   u'thirdda01',
#   u'thomais01',
#   u'thomaji01',
#   u'thompbe01',
#   u'thompla01',
#   u'thompmy01',
#   u'thomppa01',
#   u'thorpot01',
#   u'threase01',
#   u'toneyan01',
#   u'towneli01',
#   u'tripuke01',
#   u'tucketr01',
#   u'turneel01',
#   u'turneje01',
#   u'turpime01',
#   u'tylerte01',
#   u'valenda01',
#   u'vandeki01',
#   u'verhope01',
#   u'vinceja01',
#   u'vraneda01',
#   u'waitegr01',
#   u'walkeda01',
#   u'waltobi01',
#   u'warribr01',
#   u'wedmasc01',
#   u'westma01',
#   u'whatlen01',
#   u'whitero01',
#   u'whitewi01',
#   u'whiteje01',
#   u'wiggimi01',
#   u'wilkeja01',
#   u'wilkido01',
#   u'wilkied01',
#   u'wilkije01',
#   u'wilkida01',
#   u'willibu01',
#   u'willigu01',
#   u'willigu02',
#   u'willihe01',
#   u'willike01',
#   u'willira01',
#   u'willisa02',
#   u'willisl01',
#   u'willike02',
#   u'wilsomi01',
#   u'wilsoot01',
#   u'wittmra01',
#   u'woodal01',
#   u'woodle01',
#   u'woodsmi01',
#   u'woolror01',
#   u'worthja01',
#   u'youngda01',
#   u'youngmi01']]
